# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import sys
sys.path.append('..')

import pepper
from pepper import SimulationFdfd_TE, SimulationFdfd_TM
# Out:
# [13:45:25] INFO     Using client version: 1.9.1                                                     ]8;id=764185;file:///Users/lucasgrosjean/.pyenv/versions/3.11.2/envs/pepper/lib/python3.11/site-packages/tidy3d/__init__.py\__init__.py]8;;\:]8;id=618537;file:///Users/lucasgrosjean/.pyenv/versions/3.11.2/envs/pepper/lib/python3.11/site-packages/tidy3d/__init__.py#115\115]8;;\

# %% [markdown]
# ### Quickly define the size of the simulation

# %%
um = 1e-6
nm = 1e-9
Lx = 10 * um
Ly = 5 * um

dL = 50 * nm

# %%
Nx = int(Lx / dL)
Ny = int(Ly / dL)

print(f"Size: {Nx} x {Ny}")
# Out:
# Size: 199 x 99

# %%
eps = np.ones((Nx, Ny)) * 5.0
extent = [0, Lx, 0, Ly]
plt.imshow(eps.T, origin='lower', extent=extent)
plt.show()

# %%
sim = SimulationFdfd_TE(eps, [dL, dL], [10, 10], wavelength=1550 * nm)

# %%
src = np.zeros_like(eps)
src[Nx // 2, Ny // 2] = 1.0

# %%
Ez = sim.solve(src)

# %%
plt.imshow(np.real(Ez).T, extent=extent, origin='lower');

# %%
sim_Hz = SimulationFdfd_TM(eps, [dL, dL], [10, 10], wavelength=1550 * nm)

# %%
Hz = sim_Hz.solve(src)

# %%
plt.imshow(np.real(Hz).T, extent=extent, origin='lower');
